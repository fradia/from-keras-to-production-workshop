# %% [markdown]
# # Load libraries

# %%
import numpy as np
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Images & OpenCV

# %%
train_image_files_path = "/keras2production/fruits/Training/"
valid_image_files_path = "/keras2production/fruits/Test/"

# %%
beispiel_bilder = !find $train_image_files_path -type f -name "*.jpg"

# %%
num_beispiel_bilder = 30
beispiel_bilder_random = random.sample(beispiel_bilder, num_beispiel_bilder)

fig = plt.figure(figsize=(12,8))

for i in range(num_beispiel_bilder):
    fig.add_subplot(5, 6, i + 1)
    plt.axis('off')
    img = plt.imread(beispiel_bilder_random[i])
    plt.imshow(img)

# %%
for i in range(num_beispiel_bilder):
    plt.subplot(4, 6, i + 1)
    plt.axis('off')
    img = plt.imread(beispiel_bilder[i])
    plt.imshow(beispiel_bilder[i])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-a59c94ea2c76> in <module>
#       3     #plt.axis('off')
#       4     #img = plt.imread(beispiel_bilder[i])
# ----> 5     plt.imshow(beispiel_bilder[i])
#
# /usr/local/lib/python3.6/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2699         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2700         resample=resample, url=url, **({"data": data} if data is not
# -> 2701         None else {}), **kwargs)
#    2702     sci(__ret)
#    2703     return __ret
#
# /usr/local/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
# ...
